# %% [markdown]
# https://docs.openaq.org/using-the-api/dates-datetimes

# %%
from dataclasses import dataclass
from typing import Optional, List, Dict, Any

@dataclass
class Meta:
    name: str
    website: str
    page: int
    limit: int
    found: int

    @classmethod
    def from_dict(cls, data: Dict[str, Any]) -> "Meta":
        return cls(
            name=data.get("name"),
            website=data.get("website"),
            page=data.get("page"),
            limit=data.get("limit"),
            found=data.get("found"),
        )

@dataclass
class Country:
    id: int
    code: str
    name: str

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Country":
        return cls(id=d["id"], code=d["code"], name=d["name"])

@dataclass
class Owner:
    id: int
    name: str

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Owner":
        return cls(id=d["id"], name=d["name"])

@dataclass
class Provider:
    id: int
    name: str

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Provider":
        return cls(id=d["id"], name=d["name"])

@dataclass
class Instrument:
    id: int
    name: str

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Instrument":
        return cls(id=d["id"], name=d["name"])

@dataclass
class Parameter:
    id: int
    name: str
    units: str
    displayName: str

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Parameter":
        return cls(
            id=d["id"],
            name=d["name"],
            units=d["units"],
            displayName=d["displayName"],
        )

@dataclass
class Sensor:
    id: int
    name: str
    parameter: Parameter

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Sensor":
        return cls(
            id=d["id"],
            name=d["name"],
            parameter=Parameter.from_dict(d["parameter"])
        )

@dataclass
class Coordinates:
    latitude: float
    longitude: float

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Coordinates":
        return cls(latitude=d["latitude"], longitude=d["longitude"])

@dataclass
class Attribution:
    name: str
    url: Optional[str]

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Attribution":
        return cls(name=d.get("name", ""), url=d.get("url"))

@dataclass
class License:
    id: int
    name: str
    attribution: Attribution
    dateFrom: Optional[str]
    dateTo: Optional[str]

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "License":
        return cls(
            id=d["id"],
            name=d["name"],
            attribution=Attribution.from_dict(d["attribution"]),
            dateFrom=d.get("dateFrom"),
            dateTo=d.get("dateTo"),
        )

@dataclass
class DateTimePair:
    utc: str
    local: str

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "DateTimePair":
        return cls(utc=d["utc"], local=d["local"])

@dataclass
class LocationResult:
    id: int
    name: str
    locality: Optional[str]
    timezone: Optional[str]
    country: Country
    owner: Owner
    provider: Provider
    isMobile: bool
    isMonitor: bool
    instruments: List[Instrument]
    sensors: List[Sensor]
    coordinates: Coordinates
    licenses: List[License]
    bounds: Optional[List[float]]
    distance: Optional[float]
    datetimeFirst: Optional[DateTimePair]
    datetimeLast: Optional[DateTimePair]

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "LocationResult":
        return cls(
            id=d["id"],
            name=d["name"],
            locality=d.get("locality"),
            timezone=d.get("timezone"),
            country=Country.from_dict(d["country"]),
            owner=Owner.from_dict(d["owner"]),
            provider=Provider.from_dict(d["provider"]),
            isMobile=d.get("isMobile", False),
            isMonitor=d.get("isMonitor", False),
            instruments=[Instrument.from_dict(x) for x in d.get("instruments", [])],
            sensors=[Sensor.from_dict(x) for x in d.get("sensors", [])],
            coordinates=Coordinates.from_dict(d["coordinates"]),
            licenses=[License.from_dict(x) for x in d.get("licenses", [])],
            bounds=d.get("bounds"),
            distance=d.get("distance"),
            datetimeFirst=DateTimePair.from_dict(d["datetimeFirst"]) if d.get("datetimeFirst") else None,
            datetimeLast=DateTimePair.from_dict(d["datetimeLast"]) if d.get("datetimeLast") else None,
        )
    
@dataclass
class Parameter:
    id: int
    name: str
    units: str
    displayName: Optional[str]

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Parameter":
        return cls(
            id=d["id"],
            name=d["name"],
            units=d["units"],
            displayName=d.get("displayName"),
        )

@dataclass
class Period:
    label: str
    interval: str
    datetimeFrom: DateTimePair
    datetimeTo: DateTimePair

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Period":
        return cls(
            label=d["label"],
            interval=d["interval"],
            datetimeFrom=DateTimePair.from_dict(d["datetimeFrom"]),
            datetimeTo=DateTimePair.from_dict(d["datetimeTo"]),
        )

@dataclass
class Coverage:
    expectedCount: int
    expectedInterval: str
    observedCount: int
    observedInterval: str
    percentComplete: float
    percentCoverage: float
    datetimeFrom: DateTimePair
    datetimeTo: DateTimePair

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Coverage":
        return cls(
            expectedCount=d["expectedCount"],
            expectedInterval=d["expectedInterval"],
            observedCount=d["observedCount"],
            observedInterval=d["observedInterval"],
            percentComplete=d["percentComplete"],
            percentCoverage=d["percentCoverage"],
            datetimeFrom=DateTimePair.from_dict(d["datetimeFrom"]),
            datetimeTo=DateTimePair.from_dict(d["datetimeTo"]),
        )

@dataclass
class FlagInfo:
    hasFlags: bool

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "FlagInfo":
        return cls(hasFlags=d["hasFlags"])

@dataclass
class Measurement:
    value: float
    flagInfo: FlagInfo
    parameter: Parameter
    period: Period
    coordinates: Optional[Dict[str, float]]
    summary: Optional[str]
    coverage: Coverage

    @classmethod
    def from_dict(cls, d: Dict[str, Any]) -> "Measurement":
        return cls(
            value=d["value"],
            flagInfo=FlagInfo.from_dict(d["flagInfo"]),
            parameter=Parameter.from_dict(d["parameter"]),
            period=Period.from_dict(d["period"]),
            coordinates=d.get("coordinates"),
            summary=d.get("summary"),
            coverage=Coverage.from_dict(d["coverage"]),
        )

# %%
import os
import requests
import json

KEY_PATH = os.path.expanduser("notebooks/openaq_api_key")
with open(KEY_PATH, "r") as f:
    API_KEY = f.read().strip()

headers = {"X-API-Key": API_KEY}

url = "https://api.openaq.org/v3/locations/9369"
resp = requests.get(url, headers=headers, timeout=30)
resp.raise_for_status()

data = resp.json()
print(json.dumps(data, indent=2, ensure_ascii=False))

meta = Meta.from_dict(data["meta"])
print(meta)

locations: List[LocationResult] = [LocationResult.from_dict(x) for x in data.get("results", [])]
print(locations)
# Out:
# {
#   "meta": {
#     "name": "openaq-api",
#     "website": "/",
#     "page": 1,
#     "limit": 100,
#     "found": 1
#   },
#   "results": [
#     {
#       "id": 9369,
#       "name": "IS-1",
#       "locality": "IASI",
#       "timezone": "Europe/Bucharest",
#       "country": {
#         "id": 74,
#         "code": "RO",
#         "name": "Romania"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 70,
#         "name": "EEA"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 7851678,
#           "name": "co µg/m³",
#           "parameter": {
#             "id": 4,
#             "name": "co",
#             "units": "µg/m³",
#             "displayName": "CO mass"
#           }
#         },
#         {
#           "id": 28602,
#           "name": "no2 µg/m³",
#           "parameter": {
#             "id": 5,
#             "name": "no2",
#             "units": "µg/m³",
#             "displayName": "NO₂ mass"
#           }
#         },
#         {
#           "id": 1853201,
#           "name": "pm10 µg/m³",
#           "parameter": {
#             "id": 1,
#             "name": "pm10",
#             "units": "µg/m³",
#             "displayName": "PM10"
#           }
#         },
#         {
#           "id": 1853199,
#           "name": "pm25 µg/m³",
#           "parameter": {
#             "id": 2,
#             "name": "pm25",
#             "units": "µg/m³",
#             "displayName": "PM2.5"
#           }
#         },
#         {
#           "id": 7851681,
#           "name": "so2 µg/m³",
#           "parameter": {
#             "id": 6,
#             "name": "so2",
#             "units": "µg/m³",
#             "displayName": "SO₂ mass"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 47.15683599990919,
#         "longitude": 27.57490799971823
#       },
#       "licenses": [
#         {
#           "id": 10,
#           "name": "ODC-BY",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-11-17",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         27.57490799971823,
#         47.15683599990919,
#         27.57490799971823,
#         47.15683599990919
#       ],
#       "distance": null,
#       "datetimeFirst": {
#         "utc": "2020-07-30T20:00:00Z",
#         "local": "2020-07-30T23:00:00+03:00"
#       },
#       "datetimeLast": {
#         "utc": "2025-08-17T01:00:00Z",
#         "local": "2025-08-17T04:00:00+03:00"
#       }
#     }
#   ]
# }
# Meta(name='openaq-api', website='/', page=1, limit=100, found=1)
# [LocationResult(id=9369, name='IS-1', locality='IASI', timezone='Europe/Bucharest', country=Country(id=74, code='RO', name='Romania'), owner=Owner(id=4, name='Unknown Governmental Organization'), provider=Provider(id=70, name='EEA'), isMobile=False, isMonitor=True, instruments=[Instrument(id=2, name='Government Monitor')], sensors=[Sensor(id=7851678, name='co µg/m³', parameter=Parameter(id=4, name='co', units='µg/m³', displayName='CO mass')), Sensor(id=28602, name='no2 µg/m³', parameter=Parameter(id=5, name='no2', units='µg/m³', displayName='NO₂ mass')), Sensor(id=1853201, name='pm10 µg/m³', parameter=Parameter(id=1, name='pm10', units='µg/m³', displayName='PM10')), Sensor(id=1853199, name='pm25 µg/m³', parameter=Parameter(id=2, name='pm25', units='µg/m³', displayName='PM2.5')), Sensor(id=7851681, name='so2 µg/m³', parameter=Parameter(id=6, name='so2', units='µg/m³', displayName='SO₂ mass'))], coordinates=Coordinates(latitude=47.15683599990919, longitude=27.57490799971823), licenses=[License(id=10, name='ODC-BY', attribution=Attribution(name='Unknown Governmental Organization', url=None), dateFrom='2016-11-17', dateTo=None)], bounds=[27.57490799971823, 47.15683599990919, 27.57490799971823, 47.15683599990919], distance=None, datetimeFirst=DateTimePair(utc='2020-07-30T20:00:00Z', local='2020-07-30T23:00:00+03:00'), datetimeLast=DateTimePair(utc='2025-08-17T01:00:00Z', local='2025-08-17T04:00:00+03:00'))]

# %%
for loc in locations:
    print(f"\nLocation: {loc.name} ({loc.locality})")
csv.gz to data/openaq/9369/2025/month=05/location-9369-20250519.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250517.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250517.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250522.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250522.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250524.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250524.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250520.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250520.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250523.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250523.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250521.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250521.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250525.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250525.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250526.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250526.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250530.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250530.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250529.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250529.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250527.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250527.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250531.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250531.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250528.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250528.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250501.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250501.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250602.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250602.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250604.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250604.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250603.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250603.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250605.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250605.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250608.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250608.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250610.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250610.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250606.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250606.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250612.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250612.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250611.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250611.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250609.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250609.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=05/location-9369-20250511.csv.gz to data/openaq/9369/2025/month=05/location-9369-20250511.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250614.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250614.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250615.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250615.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250616.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250616.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250617.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250617.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250607.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250607.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250619.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250619.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250620.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250620.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250621.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250621.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250622.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250622.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250623.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250623.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250601.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250601.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250624.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250624.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250627.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250627.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250628.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250628.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250629.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250629.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250626.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250626.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250630.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250630.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250702.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250702.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250703.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250703.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250705.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250705.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250704.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250704.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250706.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250706.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250709.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250709.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250708.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250708.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250710.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250710.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250707.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250707.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250712.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250712.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250713.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250713.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250711.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250711.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250715.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250715.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250714.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250714.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250716.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250716.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250718.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250718.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250721.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250721.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250719.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250719.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250720.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250720.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250717.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250717.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250722.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250722.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250723.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250723.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250724.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250724.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250726.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250726.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250725.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250725.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250728.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250728.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250730.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250730.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250727.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250727.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250731.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250731.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250729.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250729.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250618.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250618.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250801.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250801.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250802.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250802.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250803.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250803.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=07/location-9369-20250701.csv.gz to data/openaq/9369/2025/month=07/location-9369-20250701.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250804.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250804.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=06/location-9369-20250625.csv.gz to data/openaq/9369/2025/month=06/location-9369-20250625.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250805.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250805.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250806.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250806.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250807.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250807.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250809.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250809.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250811.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250811.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250812.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250812.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250808.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250808.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250810.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250810.csv.gz
# download: s3://openaq-data-archive/records/csv.gz/locationid=9369/year=2025/month=08/location-9369-20250813.csv.gz to data/openaq/9369/2025/month=08/location-9369-20250813.csv.gz

# %%
from pathlib import Path
import pandas as pd

BASE = Path("data/openaq/9369")
YEARS = range(2020, 2026)  # inclusive
OUT = "data/combined_openaq_9369_2020_2025.csv"

CHUNKSIZE = 100_000
first_write = True

for y in YEARS:
    year_dir = BASE / str(y)
    if not year_dir.exists():
        continue

    # find all gzipped CSVs recursively
    files = sorted(year_dir.rglob("*.csv.gz"))
    for f in files:
        # stream in chunks
        for chunk in pd.read_csv(f, compression="gzip", chunksize=CHUNKSIZE, low_memory=False):
            chunk.to_csv(
                OUT,
                mode="w" if first_write else "a",
                index=False,
                header=first_write
            )
            if first_write:
                first_write = False
    print(f"Finished year {y}, {len(files)} files merged.")

print(f"Done. Combined CSV saved at {OUT}")
# Out:
# Finished year 2020, 143 files merged.
# Finished year 2021, 336 files merged.
# Finished year 2022, 92 files merged.
# Finished year 2023, 0 files merged.
# Finished year 2024, 306 files merged.
# Finished year 2025, 223 files merged.
# Done. Combined CSV saved at data/combined_openaq_9369_2020_2025.csv

# %%
BASE_URL = "https://www.ncei.noaa.gov/pub/data/noaa/isd-lite"
STATION_USAF = "150900"          # Iași (LRIA) WMO/USAF code
WBAN_CANDIDATES = ["99999", "00000"]  # try both, some stations use 00000
YEARS = range(2020, 2026)        # inclusive 2020..2025
OUTDIR = Path("data/meteo/isd-lite/150900")
OUTDIR.mkdir(parents=True, exist_ok=True)
TIMEOUT = 60

def download_isd_lite_year(year: int) -> bool:
    """
    Try downloading 150900-<WBAN>-<year>.gz from the NOAA ISD-Lite HTTPS directory.
    Returns True if a file was downloaded or already exists, False if not found.
    """
    for wban in WBAN_CANDIDATES:
        fname = f"{STATION_USAF}-{wban}-{year}.gz"
        url = f"{BASE_URL}/{year}/{fname}"
        out = OUTDIR / fname
        if out.exists() and out.stat().st_size > 0:
            print(f"[skip] {out} (exists)")
            return True
        try:
            # HEAD first (fast 404 check), then GET if exists
            h = requests.head(url, timeout=TIMEOUT)
            if h.status_code == 200:
                print(f"[get ] {url}")
                r = requests.get(url, timeout=TIMEOUT)
                r.raise_for_status()
                out.write_bytes(r.content)
                print(f"[save] {out} ({out.stat().st_size:,} bytes)")
                return True
            else:
                # try next WBAN candidate
                continue
        except requests.RequestException as e:
            print(f"[warn] {url} -> {e}; trying next candidate...")
            continue
    print(f"[miss] No file found for year {year} (tried WBAN={WBAN_CANDIDATES})")
    return False

if __name__ == "__main__":
    for y in YEARS:
        download_isd_lite_year(y)
# Out:
# [skip] data/meteo/isd-lite/150900/150900-99999-2020.gz (exists)
# [skip] data/meteo/isd-lite/150900/150900-99999-2021.gz (exists)
# [skip] data/meteo/isd-lite/150900/150900-99999-2022.gz (exists)
# [skip] data/meteo/isd-lite/150900/150900-99999-2023.gz (exists)
# [skip] data/meteo/isd-lite/150900/150900-99999-2024.gz (exists)
# [skip] data/meteo/isd-lite/150900/150900-99999-2025.gz (exists)

# %%
INDIR = Path("data/meteo/isd-lite/150900")
OUTFILE = Path("data/combined_isdlite_150900_2020_2025.csv")

# Define fixed-width column specs and names from ISD-Lite format
colspecs = [
    (0, 4),   # year
    (5, 7),   # month
    (8, 10),  # day
    (11, 13), # hour
    (14, 19), # air temperature
    (20, 25), # dew point
    (26, 32), # sea level pressure
    (33, 36), # wind direction
    (37, 41), # wind speed
    (42, 45), # sky cover
    (46, 49), # precipitation depth
]
names = [
    "year","month","day","hour",
    "temp_C","dewpoint_C","slp_hPa",
    "wind_dir_deg","wind_speed_ms","sky_cover","precip_mm"
]

frames = []
for f in sorted(INDIR.glob("*.gz")):
    print(f"Reading {f.name} ...")
    df = pd.read_fwf(f, colspecs=colspecs, names=names, compression="gzip")
    # Build datetime from components
    df["datetime"] = pd.to_datetime(df[["year","month","day","hour"]], errors="coerce")
    df = df.set_index("datetime").drop(columns=["year","month","day","hour"])
    frames.append(df)

# Concatenate all years
combined = pd.concat(frames).sort_index()

# Save as single CSV
combined.to_csv(OUTFILE)
print(f"Saved combined file -> {OUTFILE} with {len(combined):,} rows")
# Out:
# Reading 150900-99999-2020.gz ...
# Reading 150900-99999-2021.gz ...
# Reading 150900-99999-2022.gz ...
# Reading 150900-99999-2023.gz ...
# Reading 150900-99999-2024.gz ...
# Reading 150900-99999-2025.gz ...
# Saved combined file -> data/combined_isdlite_150900_2020_2025.csv with 48,674 rows
